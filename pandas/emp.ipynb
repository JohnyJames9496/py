# %%
import pandas as pd

df  = pd.read_csv("emp.csv")

df.head(7)
# Out:
#      name  gender  start_date  salary         team
# 0   Arjun    Male  2020-06-15   50000  Development
# 1   Meera  Female  2019-03-22   62000           HR
# 2   Rahul    Male  2021-01-10   45000      Testing
# 3  Anjali  Female  2018-11-05   70000   Management
# 4  Vikram    Male  2022-07-19   40000      Support
# 5   Sneha  Female  2020-09-30   55000  Development
# 6   Kiran    Male  2017-12-12   80000   Management

# %%
print(df['name'].sort_values(ascending=False))
# Out:
# 4     Vikram
# 5      Sneha
# 10     Rohan
# 2      Rahul
# 11     Pooja
# 9       Neha
# 1      Meera
# 6      Kiran
# 7      Divya
# 0      Arjun
# 3     Anjali
# 8       Amit
# Name: name, dtype: object

# %%
print(df.loc[df["salary"].idxmax()]['name'])
# Out:
# Kiran

# %%
print(df[df["gender"]=="Male"]['name'])
# Out:
# 0      Arjun
# 2      Rahul
# 4     Vikram
# 6      Kiran
# 8       Amit
# 10     Rohan
# Name: name, dtype: object

# %%
print(df['team'].unique())
# Out:
# ['Development' 'HR' 'Testing' 'Management' 'Support']

# %%
print(df[['name', 'team']])
# Out:
#       name         team
# 0    Arjun  Development
# 1    Meera           HR
# 2    Rahul      Testing
# 3   Anjali   Management
# 4   Vikram      Support
# 5    Sneha  Development
# 6    Kiran   Management
# 7    Divya           HR
# 8     Amit      Testing
# 9     Neha      Support
# 10   Rohan  Development
# 11   Pooja   Management
