# %%
import pandas as pd
df = pd.read_csv('students.csv')
print(df['name'].sort_values())
# Out:
# 8      Amit
# 3    Anjali
# 0     Arjun
# 7     Divya
# 6     Kiran
# 1     Meera
# 9      Neha
# 2     Rahul
# 5     Sneha
# 4    Vikram
# Name: name, dtype: object

# %%
print(df.sort_values(by='grade',ascending=False)['name'])
# Out:
# 5     Sneha
# 1     Meera
# 9      Neha
# 7     Divya
# 3    Anjali
# 0     Arjun
# 8      Amit
# 4    Vikram
# 2     Rahul
# 6     Kiran
# Name: name, dtype: object

# %%
print(df.loc[df['grade'].idxmax(), 'name'])
# Out:
# Sneha

# %%
print(df[df['gender']=="Male"]['name'])
# Out:
# 0     Arjun
# 2     Rahul
# 4    Vikram
# 6     Kiran
# 8      Amit
# Name: name, dtype: object
