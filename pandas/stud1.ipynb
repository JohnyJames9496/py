# %%
import pandas as pd

df = pd.read_csv("stud1.csv")

print(df['CGPA'].mean())
# Out:
# 8.766666666666666

# %%
print(df[df['CGPA']>9])
# Out:
#       Name Branch  Year  CGPA
# 0    Arjun    CSE     3   9.1
# 3   Anjali    CSE     1   9.5
# 5    Sneha    CSE     2   9.3
# 9     Neha    EEE     2   9.2
# 10   Rohan    CSE     4   9.6

# %%
print(df[(df['CGPA']>9) & (df['Branch']=="CSE")])
# Out:
#       Name Branch  Year  CGPA
# 0    Arjun    CSE     3   9.1
# 3   Anjali    CSE     1   9.5
# 5    Sneha    CSE     2   9.3
# 10   Rohan    CSE     4   9.6

# %%
print(df.loc[df['CGPA'].idxmax()])
# Out:
# Name      Rohan
# Branch      CSE
# Year          4
# CGPA        9.6
# Name: 10, dtype: object

# %%
print(df.groupby("Branch")['CGPA'].mean())
# Out:
# Branch
# CE     7.50
# CSE    9.26
# ECE    8.85
# EEE    8.70
# ME     8.15
# Name: CGPA, dtype: float64
